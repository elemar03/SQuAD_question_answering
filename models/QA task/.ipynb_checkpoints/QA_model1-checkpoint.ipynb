# %% [markdown]
# # Baseline: Embedding + Flatten Model for QA
# ---
#
# ### Get the preprocessed data

# %%
# %run ./_pre_model.ipynb
# Out:
# ** One-hot encoding the labels in two tensors . . .
# ** One-hot encoding the labels in two tensors . . .
# (80377, 263)
# Done.

# %% [markdown]
# ---
# ## Model

# %%
context_input = Input(shape=(c_maxlen,), dtype='int32', name='context_input')
question_input = Input(shape=(q_maxlen,), dtype='int32', name='question_input')

context_embedding = Embedding(output_dim=256, input_dim=vocabulary_size,
                         input_length=c_maxlen, name='context_embedding')(context_input)

question_embedding = Embedding(output_dim=256, input_dim=vocabulary_size, 
                         input_length=q_maxlen, name='question_embedding')(question_input)

encoded_contexts = Flatten(name='flatten_contexts')(context_embedding)
encoded_questions = Flatten(name='flatten_questions')(question_embedding)
merge1 = concatenate([encoded_questions, encoded_contexts], axis=-1, name='merge1')

start_output = Dense(c_maxlen, activation='softmax', name='start')(merge1)
output_merge = concatenate([merge1, start_output], name='merge2')
end_output = Dense(c_maxlen, activation='softmax', name='end')(output_merge)



model = Model([context_input, question_input], [start_output, end_output])

rms = optimizers.RMSprop(lr=0.001)
model.compile(optimizer=rms, loss='categorical_crossentropy', metrics=['acc'])


model.summary()

tb = TensorBoard(log_dir='models_logs/baseline')
mc = ModelCheckpoint('../saved_models/baseline_best.h5', monitor='val_loss', mode='min', save_best_only=True)
                 
history = model.fit([train_data['contexts'], train_data['questions']],
                    [train_data['start_wordloc'], train_data['end_wordloc']],
                    epochs=20,
                    batch_size=1024,
                    validation_split=0.2,
                    callbacks=[tb, mc])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# question_input (InputLayer)     (None, 60)           0
# __________________________________________________________________________________________________
# context_input (InputLayer)      (None, 263)          0
# __________________________________________________________________________________________________
# question_embedding (Embedding)  (None, 60, 256)      26374144    question_input[0][0]
# __________________________________________________________________________________________________
# context_embedding (Embedding)   (None, 263, 256)     26374144    context_input[0][0]
# __________________________________________________________________________________________________
# flatten_questions (Flatten)     (None, 15360)        0           question_embedding[0][0]
# __________________________________________________________________________________________________
# flatten_contexts (Flatten)      (None, 67328)        0           context_embedding[0][0]
# __________________________________________________________________________________________________
# merge1 (Concatenate)            (None, 82688)        0           flatten_questions[0][0]
#                                                                  flatten_contexts[0][0]
# __________________________________________________________________________________________________
# start (Dense)                   (None, 263)          21747207    merge1[0][0]
# __________________________________________________________________________________________________
# merge2 (Concatenate)            (None, 82951)        0           merge1[0][0]
#                                                                  start[0][0]
# __________________________________________________________________________________________________
# end (Dense)                     (None, 263)          21816376    merge2[0][0]
# ==================================================================================================
# Total params: 96,311,871
# Trainable params: 96,311,871
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 64301 samples, validate on 16076 samples
# Epoch 1/20
# 64301/64301 [==============================] - 12s 180us/step - loss: 9.7042 - start_loss: 4.8709 - end_loss: 4.8333 - start_acc: 0.0294 - end_acc: 0.0265 - val_loss: 9.4587 - val_start_loss: 4.8075 - val_end_loss: 4.6512 - val_start_acc: 0.0303 - val_end_acc: 0.0440
# Epoch 2/20
# 64301/64301 [==============================] - 11s 177us/step - loss: 7.5911 - start_loss: 3.8881 - end_loss: 3.7029 - start_acc: 0.1004 - end_acc: 0.1128 - val_loss: 9.1269 - val_start_loss: 4.6776 - val_end_loss: 4.4493 - val_start_acc: 0.0399 - val_end_acc: 0.0549
# Epoch 3/20
# 64301/64301 [==============================] - 11s 176us/step - loss: 6.0984 - start_loss: 3.1189 - end_loss: 2.9795 - start_acc: 0.1626 - end_acc: 0.1629 - val_loss: 9.0627 - val_start_loss: 4.6499 - val_end_loss: 4.4128 - val_start_acc: 0.0464 - val_end_acc: 0.0571
# Epoch 4/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 5.1234 - start_loss: 2.6121 - end_loss: 2.5112 - start_acc: 0.2078 - end_acc: 0.2055 - val_loss: 9.1372 - val_start_loss: 4.6816 - val_end_loss: 4.4557 - val_start_acc: 0.0473 - val_end_acc: 0.0579
# Epoch 5/20
# 64301/64301 [==============================] - 9s 146us/step - loss: 4.4046 - start_loss: 2.2385 - end_loss: 2.1661 - start_acc: 0.2627 - end_acc: 0.2599 - val_loss: 9.2054 - val_start_loss: 4.7184 - val_end_loss: 4.4871 - val_start_acc: 0.0460 - val_end_acc: 0.0559
# Epoch 6/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 3.8294 - start_loss: 1.9405 - end_loss: 1.8889 - start_acc: 0.3319 - end_acc: 0.3297 - val_loss: 9.2940 - val_start_loss: 4.7650 - val_end_loss: 4.5291 - val_start_acc: 0.0477 - val_end_acc: 0.0573
# Epoch 7/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 3.3305 - start_loss: 1.6856 - end_loss: 1.6449 - start_acc: 0.4130 - end_acc: 0.4136 - val_loss: 9.4065 - val_start_loss: 4.8251 - val_end_loss: 4.5814 - val_start_acc: 0.0468 - val_end_acc: 0.0561
# Epoch 8/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 2.8945 - start_loss: 1.4631 - end_loss: 1.4314 - start_acc: 0.4980 - end_acc: 0.5003 - val_loss: 9.4569 - val_start_loss: 4.8492 - val_end_loss: 4.6078 - val_start_acc: 0.0464 - val_end_acc: 0.0565
# Epoch 9/20
# 64301/64301 [==============================] - 9s 146us/step - loss: 2.5003 - start_loss: 1.2640 - end_loss: 1.2363 - start_acc: 0.5782 - end_acc: 0.5796 - val_loss: 9.5950 - val_start_loss: 4.9103 - val_end_loss: 4.6848 - val_start_acc: 0.0462 - val_end_acc: 0.0549
# Epoch 10/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 2.1420 - start_loss: 1.0851 - end_loss: 1.0569 - start_acc: 0.6513 - end_acc: 0.6594 - val_loss: 9.6859 - val_start_loss: 4.9624 - val_end_loss: 4.7236 - val_start_acc: 0.0461 - val_end_acc: 0.0552
# Epoch 11/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 1.8165 - start_loss: 0.9219 - end_loss: 0.8946 - start_acc: 0.7194 - end_acc: 0.7275 - val_loss: 9.8165 - val_start_loss: 5.0294 - val_end_loss: 4.7871 - val_start_acc: 0.0451 - val_end_acc: 0.0547
# Epoch 12/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 1.5250 - start_loss: 0.7779 - end_loss: 0.7471 - start_acc: 0.7766 - end_acc: 0.7859 - val_loss: 10.0112 - val_start_loss: 5.1223 - val_end_loss: 4.8889 - val_start_acc: 0.0442 - val_end_acc: 0.0541
# Epoch 13/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 1.2706 - start_loss: 0.6510 - end_loss: 0.6196 - start_acc: 0.8241 - end_acc: 0.8327 - val_loss: 10.0571 - val_start_loss: 5.1545 - val_end_loss: 4.9026 - val_start_acc: 0.0424 - val_end_acc: 0.0513
# Epoch 14/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 1.0489 - start_loss: 0.5398 - end_loss: 0.5091 - start_acc: 0.8638 - end_acc: 0.8697 - val_loss: 10.2554 - val_start_loss: 5.2525 - val_end_loss: 5.0029 - val_start_acc: 0.0431 - val_end_acc: 0.0532
# Epoch 15/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 0.8652 - start_loss: 0.4477 - end_loss: 0.4175 - start_acc: 0.8911 - end_acc: 0.8979 - val_loss: 10.3762 - val_start_loss: 5.3096 - val_end_loss: 5.0667 - val_start_acc: 0.0409 - val_end_acc: 0.0516
# Epoch 16/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 0.7107 - start_loss: 0.3695 - end_loss: 0.3412 - start_acc: 0.9134 - end_acc: 0.9188 - val_loss: 10.5160 - val_start_loss: 5.3844 - val_end_loss: 5.1316 - val_start_acc: 0.0402 - val_end_acc: 0.0512
# Epoch 17/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 0.5818 - start_loss: 0.3043 - end_loss: 0.2775 - start_acc: 0.9301 - end_acc: 0.9362 - val_loss: 10.7275 - val_start_loss: 5.4887 - val_end_loss: 5.2388 - val_start_acc: 0.0399 - val_end_acc: 0.0487
# Epoch 18/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 0.4803 - start_loss: 0.2517 - end_loss: 0.2286 - start_acc: 0.9442 - end_acc: 0.9476 - val_loss: 10.8883 - val_start_loss: 5.5731 - val_end_loss: 5.3152 - val_start_acc: 0.0378 - val_end_acc: 0.0491
# Epoch 19/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 0.3994 - start_loss: 0.2091 - end_loss: 0.1903 - start_acc: 0.9538 - end_acc: 0.9568 - val_loss: 11.0098 - val_start_loss: 5.6345 - val_end_loss: 5.3753 - val_start_acc: 0.0371 - val_end_acc: 0.0485
# Epoch 20/20
# 64301/64301 [==============================] - 9s 147us/step - loss: 0.3341 - start_loss: 0.1749 - end_loss: 0.1592 - start_acc: 0.9606 - end_acc: 0.9635 - val_loss: 11.1674 - val_start_loss: 5.7167 - val_end_loss: 5.4508 - val_start_acc: 0.0361 - val_end_acc: 0.0467

# %% [markdown]
# ---
# ## Evaluating Model

# %%
# %run ../../evaluation/evaluate.ipynb
#saved_model = load_model('../saved_models/baseline_best.h5')# load a saved model

#print(history.history)

print("Evaluating the model . . . \n")
train_data['start_pred'], train_data['end_pred'] = model.predict([train_data['contexts'], train_data['questions']])

dev_data['start_pred'], dev_data['end_pred'] = model.predict([dev_data['contexts'], dev_data['questions']])

evaluation_main(train_data, dev_data, model, history.history)


#print("\n\n\nEvaluating the saved best model . . . \n")
#train_data['start_pred'], train_data['end_pred'] = saved_model.predict([train_data['contexts'],
#                                                                  train_data['questions']], verbose=1)
#dev_data['start_pred'], dev_data['end_pred'] = saved_model.predict([dev_data['contexts'],
#                                                              dev_data['questions']], verbose=1)
#evaluation_main(train_data, dev_data, saved_model, history.history)
# Out:
# Evaluating the model . . .
#
# 80377/80377 [==============================] - 10s 130us/step
# 9652/9652 [==============================] - 1s 128us/step
#
# ______________________________________________________________________________________________________________
#
#                                       TRAINING LOSS AND ACCURACY PLOTS
# ______________________________________________________________________________________________________________
# ______________________________________________________________________________________________________________
#
#                                          EVALUATION ON TRAINING SET
# ______________________________________________________________________________________________________________
#
#                           EM:  77.99868121477537 ;     F1:  79.2226117949675
#
#                           loss  =  2.3967632165879365
#                           start_loss  =  1.2285335009677838
#                           end_loss  =  1.1682297168650524
#                           start_acc  =  0.789715963521903
#                           end_acc  =  0.7922664443808553
# ______________________________________________________________________________________________________________
#
#                                         EVALUATION ON DEVELOPMENT SET
# ______________________________________________________________________________________________________________
#
#                           EM:  1.2950683796104434 ;     F1:  5.658901788596042
#
#                           loss  =  11.067800104494566
#                           start_loss  =  5.691405121636895
#                           end_loss  =  5.37639497040813
#                           start_acc  =  0.04258184832313522
#                           end_acc  =  0.05211355159552424
